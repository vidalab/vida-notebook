# %% [markdown]
# <div class="section">
# <h1 class="header">Data visualizations for IPython notebook</h1>
# <br>
# Made by <a href="https://vida.io">vida.io</a>.
# <br>
# Question or comment. Send to <a href="mailto:contact@vida.io?Subject=IPython">contact@vida.io</a>.
# </div>

# %% [markdown]
# <h2>Tree, Treemap, Sandkey</h2>
# <div class="section">
# <a href="./tree.ipynb" data-content="Tree" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/dMog8pWr8mF4Sr2hk"/>
# </a>
# <a href="./treemap.ipynb" data-content="Treemap" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/chgwCKJJnKh7soEcQ"/>
# </a>
# <a href="./sankey.ipynb" data-content="Sandkey" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/yB7uTByGsAwiZQFDZ"/>
# </a>
# </div>
# <div class="section">
# <a href="./chord.ipynb" data-content="Chord" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/DKd53fYLpQbHCp4Be"/>
# </a>
# </div>
# <h2>Network</h2>
# <div class="section">
# <a href="./force_directed_graph.ipynb" data-content="Force Directed Graph" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/EfEFQqPE25GCMbhi9"/>
# </a>
# <a href="./relationship_force.ipynb" data-content="Relationship Force" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/qZ5SJdRJfj3XmSXYJ"/>
# </a>
# <a href="./collapsible_force.ipynb" data-content="Collapsible Force" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/sy7vzWW7BJEvKdZeL"/>
# </a>
# </div>
# <div class="section">
# <a href="./group_force.ipynb" data-content="Group Force" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/YPrKeBgdSybuvhpDr"/>
# </a>
# </div>
# <h2>Map</h2>
# <div class="section">
# <a href="./us_choropleth.ipynb" data-content="US Choropleth" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/4yATR8Z7T99KY4dzg"/>
# </a>
# <a href="./us_choropleth_bar.ipynb" data-content="US Choropleth Bar" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/4vZ9mRGyepoyQxFcK"/>
# </a>
# <a href="./us_counties_choropleth.ipynb" data-content="US Counties Choropleth" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/qyRt8bFozMqfaw6Av"/>
# </a>
# </div>
# <div class="section">
# <a href="./us_map_side_by_side.ipynb" data-content="US Map Side by Side" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/3xHNc7JCLGRWoq9BG"/>
# </a>
# <a href="./us_map_years.ipynb" data-content="US Map over Years" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/xkDY35osmTCrLSfXB"/>
# </a>
# <a href="./world.ipynb" data-content="World" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/fjuXHEcEwEh55dopa"/>
# </a>
# </div>
# <div class="section">
# <a href="./india.ipynb" data-content="India" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/ALTQMueeCrypLNj34"/>
# </a>
# <a href="./uk.ipynb" data-content="UK" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/WQAzwYDdDQb5byXsH"/>
# </a>
# </div>
# <h2>3D</h2>
# <div class="section">
# <a href="./surface_plot.ipynb" data-content="Surface Plot" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/BJXoQv89L3RkG574p"/>
# </a>
# <a href="./bar_plot.ipynb" data-content="Bar Plot" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/hK4waAHeTRjuNjSr2"/>
# </a>
# <a href="./3d_force.ipynb" data-content="3D Force" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/fDn4mDHX26H9hcyHu"/>
# </a>
# </div>
# <h2>Charts</h2>
# <div class="section">
# <a href="./column_chart.ipynb" data-content="Column" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/7kAhqrG4C4eDxEmvP"/>
# </a>
# <a href="./bar_chart.ipynb" data-content="Bar" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/PaQKpZWohsxJZsfQQ"/>
# </a>
# <a href="./bubble_chart.ipynb" data-content="Bubble" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/uqctrZDsecBWCWvBv"/>
# </a>
# <a href="./multiple_lines_chart.ipynb" data-content="Multiple Lines" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/KgriW9x294QS4r62G"/>
# </a>
# <a href="./multiple_bar_chart.ipynb" data-content="Multiple Bar" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/ZCzewTza4ZSzMWSBG"/>
# </a>
# <a href="./line_chart.ipynb" data-content="Line" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/QZZTrhk7SmfChczYp"/>
# </a>
# </div>
# <div class="section">
# <a href="./donut_chart.ipynb" data-content="Donut" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/KrvKJKJjzQKotTjzQ"/>
# </a>
# <a href="./multiple_donut_chart.ipynb" data-content="Multiple Donut" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/WgBMc4zDWF7YpqXGR"/>
# </a>
# <a href="./group_bar_chart.ipynb" data-content="Group Bar" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/sEYXnxDfdxXn824QH"/>
# </a>
# <a href="./pie_chart.ipynb" data-content="Pie" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/pooDmdtX2TREKmTin"/>
# </a>
# <a href="./area_chart.ipynb" data-content="Area" class="vida-thumbnail">
# <img src="https://vida-production.s3.amazonaws.com/thumbnails/7fiwxB5XpDXY45dsb"/>
# </a>
# </div>

# %%
from IPython.core.display import display, HTML
display(HTML(open('style.css', 'r').read()));
# Out:
# <style>
# div.section {
#   width: 100%;
#   float: left;
#   margin-bottom: 40px;
# }
#
# h1.header {
#   color: steelblue;
#   font-size:40px;
# }
#
# .section h2 {
#   margin-bottom: 10px;
# }
#
# .vida-thumbnail {
#   width: 28%;
#   height: 210px;
#   float: left;
#   margin-top: 20px;
#   margin-right: 20px;
#   position: relative;
#   border: 1px solid #ddd;
#   border-radius: 4px;
#   -webkit-transition: border .2s ease-in-out;
#   transiation: border .2s ease-in-out;
# }
#
# .vida-thumbnail img {
#   height: 200px;
#   padding: 4px;
#   background-color: white;
# }
#
# .vida-thumbnail:after {
#     font-size: 40px;
#     line-height: 50px;
#     text-align: center;
#     content: attr(data-content);
#     color:#fff;
#     position: absolute;
#     width:100%; height:100%;
#     top:0px; left:0px;
#     background:rgba(0,0,0,0.6);
#     opacity:0;
#     transition: all 0.5s;
#     -webkit-transition: all 0.5s;
#     padding-left: 5px;
#     padding-right: 5px;
# ...
